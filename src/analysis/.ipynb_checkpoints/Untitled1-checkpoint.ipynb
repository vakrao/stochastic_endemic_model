# %%
import pandas as pd
import seaborn as sns
import numpy as np

dat = pd.read_csv('../age_run_1_90.csv')
total_inc_data = dat[dat.vartype == "Rt"]
total_inc_data['value'] = total_inc_data['value'].astype(float)
total_inc_data['t'] = total_inc_data['t'].astype(int)
# Out:
# /tmp/ipykernel_1298138/30274484.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_inc_data['value'] = total_inc_data['value'].astype(float)
# /tmp/ipykernel_1298138/30274484.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_inc_data['t'] = total_inc_data['t'].astype(int)

# %%
print(total_inc_data)
# Out:
#             t   vv  age     value  sim_number vartype
# 680         0  0.0  -90  4.930985           1      Rt
# 1361        1  0.0  -90  4.930984           1      Rt
# 2042        2  0.0  -90  4.930983           1      Rt
# 2723        3  0.0  -90  4.930982           1      Rt
# 3404        4  0.0  -90  4.930980           1      Rt
# ...       ...  ...  ...       ...         ...     ...
# 4968575  7295  0.0  -90  2.104495           1      Rt
# 4969256  7296  0.0  -90  2.104542           1      Rt
# 4969937  7297  0.0  -90  2.104555           1      Rt
# 4970618  7298  0.0  -90  2.104554           1      Rt
# 4971299  7299  0.0  -90  2.104490           1      Rt
#
# [7300 rows x 6 columns]

# %%
sns.lineplot(total_inc_data,x="t",y="value")
